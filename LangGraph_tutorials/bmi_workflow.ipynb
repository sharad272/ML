# %%
from typing import TypedDict

from langgraph.graph import END, START, StateGraph

# %%
# define State
class BMIState(TypedDict):
    weight: float
    height: float
    bmi: float

# %%
def calculate_bmi(state: BMIState):
    #updating the state
    state["bmi"] = state["weight"] / (state["height"] ** 2) 
    return state

# %%
# define graph
graph = StateGraph(BMIState)
# add nodes to graph
graph.add_node("calculate_bmi", calculate_bmi)

# add edges to graph
# START ->  CALCULATE_BMI -> END
graph.add_edge(START, "calculate_bmi")
graph.add_edge("calculate_bmi", END)
# compile graph
graph.compile()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 8
#       4 graph.add_node("calculate_bmi", calculate_bmi)
#       6 # add edges to graph
#       7 # START ->  CALCULATE_BMI -> END
# ----> 8 graph.add_edge(START, "calculate_bmi")
#       9 graph.add_edge("calculate_bmi", END)
#      10 # compile graph
#
# NameError: name 'START' is not defined
