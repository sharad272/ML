# %%
import os
from typing import TypedDict

from dotenv import load_dotenv
from langchain_core.messages import HumanMessage
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langgraph.graph import END, START, StateGraph

# %%
# Run cell 0 first. Instruct models: use ChatHuggingFace (chat_completion), not llm.invoke (text_generation).
load_dotenv()
token = os.getenv("HUGGINGFACEHUB_API_TOKEN") or os.getenv("HUGGINGFACE_API_KEY")
if not token:
    raise ValueError("Set HUGGINGFACE_API_KEY or HUGGINGFACEHUB_API_TOKEN in .env")
os.environ.setdefault("HUGGINGFACEHUB_API_TOKEN", token)

HF_MODEL_ID = "HuggingFaceTB/SmolLM2-1.7B-Instruct"

llm = HuggingFaceEndpoint(
    repo_id=HF_MODEL_ID,
    huggingfacehub_api_token=token,
    max_new_tokens=256,
    do_sample=False,
    temperature=0.2,
)
chat = ChatHuggingFace(llm=llm)

chat.invoke(
    [HumanMessage(content="In one short sentence, what does Hugging Face Hub provide?")]
)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[18], line 18
#       8 HF_MODEL_ID = "HuggingFaceTB/SmolLM2-1.7B-Instruct"
#      10 llm = HuggingFaceEndpoint(
#      11     repo_id=HF_MODEL_ID,
#      12     huggingfacehub_api_token=token,
#    (...)     15     temperature=0.2,
#      16 )
# ---> 18 llm.invoke("In one short sentence, what does Hugging Face Hub provide?")
#
# File c:\Users\Sharad.goyal\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\llms.py:380, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     369 @override
#     370 def invoke(
#     371     self,
#    (...)    376     **kwargs: Any,
#     377 ) -> str:
#     378     config = ensure_config(config)
#     379     return (
# --> 380         self.generate_prompt(
#     381             [self._convert_input(input)],
#     382             stop=stop,
# ...
